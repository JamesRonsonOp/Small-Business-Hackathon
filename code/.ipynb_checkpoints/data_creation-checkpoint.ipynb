# %%
import pandas as pd
import numpy as np

from faker import Faker

# %%
# instantiate a faker model
faker = Faker()

# %%
revenue_df = pd.DataFrame(columns = ['Date', 'Revenue', 'Costs', 'Profit'])

# %%
revenue_list = []
for i in range(365):
    year_one_revenue = revenue_list.append(faker

# %%
revenue_list
# Out:
# [('UGX', 'Ugandan shilling'),
#  ('GEL', 'Georgian lari'),
#  ('IDR', 'Indonesian rupiah'),
#  ('SHP', 'Saint Helena pound'),
#  ('NOK', 'Norwegian krone'),
#  ('RON', 'Romanian leu'),
#  ('LSL', 'Lesotho loti'),
#  ('ERN', 'Eritrean nakfa'),
#  ('CNY', 'Renminbi'),
#  ('BSD', 'Bahamian dollar'),
#  ('TVD', 'Tuvaluan dollar'),
#  ('SRD', 'Surinamese dollar'),
#  ('PAB', 'Panamanian balboa'),
#  ('ZAR', 'South African rand'),
#  ('MDL', 'Moldovan leu'),
#  ('LTL', 'Lithuanian litas'),
#  ('GGP', 'Guernsey pound'),
#  ('BBD', 'Barbadian dollar'),
#  ('KGS', 'Kyrgyzstani som'),
#  ('BMD', 'Bermudian dollar'),
#  ('XPF', 'CFP franc'),
#  ('SZL', 'Swazi lilangeni'),
#  ('BBD', 'Barbadian dollar'),
#  ('FKP', 'Falkland Islands pound'),
#  ('MYR', 'Malaysian ringgit'),
#  ('IDR', 'Indonesian rupiah'),
#  ('RWF', 'Rwandan franc'),
#  ('AUD', 'Australian dollar'),
#  ('NAD', 'Namibian dollar'),
#  ('KHR', 'Cambodian riel'),
#  ('KPW', 'North Korean won'),
#  ('GTQ', 'Guatemalan quetzal'),
# ...
