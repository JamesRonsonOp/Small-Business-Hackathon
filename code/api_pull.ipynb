# %%
import pandas as pd
import numpy as np

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/restaurants/search/geo"

querystring = {"lon":"-73.992378\t","lat":"40.68919","distance":"1","page":"1"}

headers = {
    'x-rapidapi-key': "SIGN-UP-FOR-KEY",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"message":"You are not subscribed to this API."}

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/menuitems/search"

querystring = {"page":"1"}

headers = {
    'x-rapidapi-key': "3f810d4109msh111049fc1ee168bp17131ajsn2b6520e7000c",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":{"totalResults":32958986,"data":[{"address":{"city":"ALPENA","formatted":"600 W Chisholm St ALPENA, MI 49707","postal_code":"49707","state":"MI","street":"600 W Chisholm St"},"cuisines":["American","Burgers","Ice Cream"],"geo":{"lat":45.067079,"lon":-83.439155},"item_id":1274122903,"menu_item_description":"chicken, shredded cheddar cheese, bacon, bits and tomatoes","menu_item_name":"Grilled Chicken Salad ","menu_item_pricing":[{"currency":"USD","price":4.29,"priceString":"$4.29"}],"price_range":"","restaurant_hours":"","restaurant_id":168494,"restaurant_name":"Dairy Queen","restaurant_phone":"(989) 354-7056","subsection":"Hot Eats - Salads","subsection_description":" "},{"address":{"city":"ALPENA","formatted":"600 W Chisholm St ALPENA, MI 49707","postal_code":"49707","state":"MI","street":"600 W Chisholm St"},"cuisines":["American","Burgers","Ice Cream"],"geo":{"lat":45.067079,"lon":-83.439155},"item_id":1274122958,"menu_item_description":"","menu_item_name":"French Fries",
# ...

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/restaurants/zip_code/89148"

querystring = {"page":"1"}

headers = {
    'x-rapidapi-key': "3f810d4109msh111049fc1ee168bp17131ajsn2b6520e7000c",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":{"totalResults":37,"data":[{"geo":{"lon":-115.297357,"lat":36.094533},"hours":"","address":{"city":"LAS VEGAS","formatted":"5180 S Fort Apache Rd LAS VEGAS, NV 89148","street":"5180 S Fort Apache Rd","state":"NV","postal_code":"89148"},"restaurant_phone":"(702) 873-6370","restaurant_id":165469,"price_range":"","menus":[],"price_range_100":0,"cuisines":["American","Mexican","Tex-Mex"],"restaurant_name":"Del Taco"},{"geo":{"lon":-115.294615,"lat":36.09383},"hours":"","address":{"city":"LAS VEGAS","formatted":"5200 S Fort Apache Rd LAS VEGAS, NV 89148","street":"5200 S Fort Apache Rd","state":"NV","postal_code":"89148"},"restaurant_phone":"","restaurant_id":196519,"price_range":"","menus":[],"price_range_100":0,"cuisines":["American","Burgers"],"restaurant_name":"McDonald's"},{"geo":{"lon":-115.287872,"lat":36.055797},"hours":"","address":{"city":"Las Vegas","formatted":"7272 El Capitan Way Las Vegas, NV 89148","street":"7272 El Capitan Way","state":"NV","postal_code":"89148"}
# ...

# %%
results_df = pd.DataFrame(response)

# %%
results_df[0][1]
# Out:
# b'ted":"5180 S Fort Apache Rd LAS VEGAS, NV 89148","street":"5180 S Fort Apache Rd","state":"NV","postal_code":"89148"},"restauran'

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/restaurants/search/ids"

querystring = {"distance":"1","page":"1","lat":"40.68919","lon":"-73.992378\t"}

headers = {
    'x-rapidapi-key': "3f810d4109msh111049fc1ee168bp17131ajsn2b6520e7000c",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"result":{"totalResults":823,"data":[{"restaurant_id":357203},{"restaurant_id":250275},{"restaurant_id":401244},{"restaurant_id":250274},{"restaurant_id":297188},{"restaurant_id":150737},{"restaurant_id":250276},{"restaurant_id":150773},{"restaurant_id":299786},{"restaurant_id":148202},{"restaurant_id":351988},{"restaurant_id":150782},{"restaurant_id":150780},{"restaurant_id":113240},{"restaurant_id":250307},{"restaurant_id":367741},{"restaurant_id":217320},{"restaurant_id":301752},{"restaurant_id":250293},{"restaurant_id":424449},{"restaurant_id":250295},{"restaurant_id":516886},{"restaurant_id":284277},{"restaurant_id":310177},{"restaurant_id":150792},{"restaurant_id":236157},{"restaurant_id":284276},{"restaurant_id":302706},{"restaurant_id":250278},{"restaurant_id":362050},{"restaurant_id":318410},{"restaurant_id":250384},{"restaurant_id":367778},{"restaurant_id":301466},{"restaurant_id":150772},{"restaurant_id":395628},{"restaurant_id":250267},{"restaurant_id":509610},{"restaura
# ...

# %%
id_results_dict = response.text

# %%
type(id_results_dict)
# Out:
# str

# %%
id_results[0][19]
# Out:
# b':150799},{"restaurant_id":386827},{"restaurant_id":363522},{"restaurant_id":273462},{"restaurant_id":365781}],"numResults":100,"'

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/restaurant/%7Bid%7D/menuitems"

querystring = {"page":"1"}

headers = {
    'x-rapidapi-key': "3f810d4109msh111049fc1ee168bp17131ajsn2b6520e7000c",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# Service Unavailable

# %%
import requests

url = "https://us-restaurant-menus.p.rapidapi.com/restaurant/%7Bid%7D/menuitems"

querystring = {"page":"1"}

headers = {
    'x-rapidapi-key': "3f810d4109msh111049fc1ee168bp17131ajsn2b6520e7000c",
    'x-rapidapi-host': "us-restaurant-menus.p.rapidapi.com"
    }

response = requests.request("GET", url, stream=True, headers=headers, params=querystring)

print(response.text)
# Out:
# Service Unavailable
